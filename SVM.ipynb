# %%
import os
import numpy as np
import tensorflow as tf

import warnings
warnings.filterwarnings('ignore')

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.6
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)

training_set = datagen.flow_from_directory(
        "DogandCat/training_set/",
        target_size=(64, 64),
        batch_size=32,
        class_mode="binary"
      )
# Out:
# Found 8005 images belonging to 2 classes.

# %%
datagen1 = ImageDataGenerator(rescale=1./255)

test_set = datagen1.flow_from_directory(
        "DogandCat/test_set",
        target_size=(64, 64),
        batch_size=32,
        class_mode="binary"
      )
# Out:
# Found 2023 images belonging to 2 classes.

# %%
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import Dense

# %%
from tensorflow.keras.regularizers import l2

# %%
cnn = tf.keras.models.Sequential()
# Out:
# WARNING:tensorflow:From C:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32,padding="same",kernel_size=3, activation='relu', strides=2, input_shape=[64, 64, 3]))

# %%
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))
# Out:
# WARNING:tensorflow:From C:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32,padding='same',kernel_size=3, activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %%
cnn.add(tf.keras.layers.Flatten())

# %%
cnn.add(tf.keras.layers.Dense(units=128, activation='relu'))

# %%
cnn.add(Dense(1, kernel_regularizer=tf.keras.regularizers.l2(0.01),activation
             ='linear'))

# %%
cnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  max_pooling2d (MaxPooling2  (None, 16, 16, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 16, 16, 32)        9248
#
#  max_pooling2d_1 (MaxPoolin  (None, 8, 8, 32)          0
#  g2D)
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 128)               262272
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 272545 (1.04 MB)
# Trainable params: 272545 (1.04 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
cnn.compile(optimizer = 'adam', loss = 'hinge', metrics = ['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
r=cnn.fit(x = training_set, validation_data = test_set, epochs = 15)
# Out:
# Epoch 1/15
# WARNING:tensorflow:From C:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 251/251 [==============================] - 200s 783ms/step - loss: 0.9013 - accuracy: 0.5619 - val_loss: 0.7691 - val_accuracy: 0.6782
# Epoch 2/15
# 251/251 [==============================] - 52s 206ms/step - loss: 0.7219 - accuracy: 0.6645 - val_loss: 0.6560 - val_accuracy: 0.6975
# Epoch 3/15
# 251/251 [==============================] - 54s 216ms/step - loss: 0.6706 - accuracy: 0.6849 - val_loss: 0.6784 - val_accuracy: 0.7286
# Epoch 4/15
# 251/251 [==============================] - 61s 243ms/step - loss: 0.6263 - accuracy: 0.7041 - val_loss: 0.6126 - val_accuracy: 0.7504
# Epoch 5/15
# 251/251 [==============================] - 51s 203ms/step - loss: 0.5955 - accuracy: 0.7187 - val_loss: 0.6176 - val_accuracy: 0.7548
# Epoch 6/15
# 251/251 [==============================] - 49s 196ms/step - loss: 0.5755 - accuracy: 0.7317 - val_loss: 0.5619 - val_accuracy: 0.7687
# Epoch 7/15
# 251/251 [==============================] - 51s 203ms/step - loss: 0.5582 - accuracy: 0.7392 - val_loss: 0.5581 - val_accuracy: 0.7622
# Epoch 8/15
# 251/251 [==============================] - 50s 201ms/step - loss: 0.5321 - accuracy: 0.7504 - val_loss: 0.5438 - val_accuracy: 0.7756
# Epoch 9/15
# 251/251 [==============================] - 49s 195ms/step - loss: 0.5256 - accuracy: 0.7573 - val_loss: 0.5310 - val_accuracy: 0.7701
# Epoch 10/15
# 251/251 [==============================] - 50s 200ms/step - loss: 0.5131 - accuracy: 0.7649 - val_loss: 0.5029 - val_accuracy: 0.7771
# Epoch 11/15
# 251/251 [==============================] - 50s 199ms/step - loss: 0.4994 - accuracy: 0.7690 - val_loss: 0.5648 - val_accuracy: 0.7820
# Epoch 12/15
# 251/251 [==============================] - 50s 201ms/step - loss: 0.4804 - accuracy: 0.7833 - val_loss: 0.4946 - val_accuracy: 0.7726
# Epoch 13/15
# 251/251 [==============================] - 50s 201ms/step - loss: 0.4741 - accuracy: 0.7794 - val_loss: 0.5231 - val_accuracy: 0.7835
# Epoch 14/15
# 251/251 [==============================] - 51s 201ms/step - loss: 0.4648 - accuracy: 0.7869 - val_loss: 0.4852 - val_accuracy: 0.7934
# Epoch 15/15
# 251/251 [==============================] - 51s 201ms/step - loss: 0.4625 - accuracy: 0.7894 - val_loss: 0.4737 - val_accuracy: 0.8023

# %%
import matplotlib.pyplot as plt
plt.plot(r.history['loss'], label='train loss')
plt.plot(r.history['val_loss'], label='val loss')
plt.legend()
plt.show()

# plot the accuracy
plt.plot(r.history['accuracy'], label='train acc')
plt.plot(r.history['val_accuracy'], label='val acc')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model

cnn.save('./model_rcat_dog.h5')

# %%
from tensorflow.keras.preprocessing import image
test_image = image.load_img('DogandCat/test_set/dogs/dog.4990.jpg', target_size = (64,64))
test_image = image.img_to_array(test_image)
test_image=test_image/255
test_image = np.expand_dims(test_image, axis = 0)
result = cnn.predict(test_image)
# Out:
# 1/1 [==============================] - 0s 42ms/step

# %%
if result[0]<0:
    print("The image classified is cat")
else:
    print("The image classified is dog")
# Out:
# The image classified is dog

# %%
file='DogandCat/test_set/dogs/dog.4990.jpg'
from PIL import Image

# %%
files = Image.open(file)
plt.imshow(files)
plt.axis('off')  # Hide the axis
plt.show()
